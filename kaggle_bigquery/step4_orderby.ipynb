# %%
import yaml
from google.cloud import bigquery

# %%
config = yaml.load(open("credentials.yml"), yaml.Loader)
client = bigquery.Client.from_service_account_json(config["credentials_path"])

# %%
dataset_ref = bigquery.DatasetReference("bigquery-public-data", "nhtsa_traffic_fatalities")
table_ref = bigquery.TableReference(dataset_ref, "accident_2015")

table = client.get_table(table_ref)
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#    state_number state_name  consecutive_number  \
# 0            30    Montana              300019
# 1            39       Ohio              390099
# 2            49       Utah              490123
# 3            48      Texas              481184
# 4            41     Oregon              410333
#
#    number_of_vehicle_forms_submitted_all  \
# 0                                      5
# 1                                      7
# 2                                     16
# 3                                      6
# 4                                     11
#
#    number_of_motor_vehicles_in_transport_mvit  \
# 0                                           5
# 1                                           7
# 2                                          16
# 3                                           5
# 4                                          11
#
#    number_of_parked_working_vehicles  \
# 0                                  0
# 1                                  0
# 2                                  0
# 3                                  1
# 4                                  0
#
#    number_of_forms_submitted_for_persons_not_in_motor_vehicles  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    number_of_persons_not_in_motor_vehicles_in_transport_mvit  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  5
# 4                                                  0
#
#    number_of_persons_in_motor_vehicles_in_transport_mvit  \
# 0                                                  7
# 1                                                 15
# 2                                                 28
# 3                                                  5
# 4                                                 14
#
#    number_of_forms_submitted_for_persons_in_motor_vehicles  ...  \
# 0                                                  7        ...
# 1                                                 15        ...
# 2                                                 28        ...
# 3                                                 10        ...
# 4                                                 14        ...
#
#    minute_of_ems_arrival_at_hospital  related_factors_crash_level_1  \
# 0                                 45                              0
# 1                                 24                             27
# 2                                 99                              0
# 3                                 99                              0
# 4                                 99                              0
#
#    related_factors_crash_level_1_name  related_factors_crash_level_2  \
# 0                                None                              0
# 1           Backup Due to Prior Crash                              0
# 2                                None                              0
# 3                                None                              0
# 4                                None                              0
#
#    related_factors_crash_level_2_name  related_factors_crash_level_3  \
# 0                                None                              0
# 1                                None                              0
# 2                                None                              0
# 3                                None                              0
# 4                                None                              0
#
#    related_factors_crash_level_3_name  number_of_fatalities  \
# 0                                None                     1
# 1                                None                     1
# 2                                None                     1
# 3                                None                     1
# 4                                None                     1
#
#    number_of_drunk_drivers        timestamp_of_crash
# 0                        0 2015-03-28 14:58:00+00:00
# 1                        0 2015-02-14 11:19:00+00:00
# 2                        0 2015-04-14 12:24:00+00:00
# 3                        0 2015-05-27 16:40:00+00:00
# 4                        0 2015-11-17 18:17:00+00:00
#
# [5 rows x 70 columns]

# %%
# Determine how the number of accidents varies with the day of the week.
query = """
    SELECT COUNT(consecutive_number) AS num_accidents, EXTRACT(DAYOFWEEK FROM timestamp_of_crash) AS day_of_week
    FROM `bigquery-public-data.nhtsa_traffic_fatalities.accident_2015`
    GROUP BY day_of_week
    ORDER BY num_accidents DESC
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**9)  # 1 GB
query_job = client.query(query, job_config=safe_config)
query_results = query_job.to_dataframe()
query_results
# Out:
#    num_accidents  day_of_week
# 0           5659            7
# 1           5298            1
# 2           4916            6
# 3           4460            5
# 4           4182            4
# 5           4038            2
# 6           3985            3

# %%
dataset_ref = bigquery.DatasetReference("bigquery-public-data", "world_bank_intl_education")
table_ref = bigquery.TableReference(dataset_ref, "international_education")

table = client.get_table(table_ref)
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   country_name country_code  \
# 0         Chad          TCD
# 1         Chad          TCD
# 2         Chad          TCD
# 3         Chad          TCD
# 4         Chad          TCD
#
#                                       indicator_name indicator_code     value  \
# 0  Enrolment in lower secondary education, both s...        UIS.E.2  321921.0
# 1  Enrolment in upper secondary education, both s...        UIS.E.3   68809.0
# 2  Enrolment in upper secondary education, both s...        UIS.E.3   30551.0
# 3  Enrolment in upper secondary education, both s...        UIS.E.3   79784.0
# 4  Repeaters in primary education, all grades, bo...        UIS.R.1  282699.0
#
#    year
# 0  2012
# 1  2006
# 2  1999
# 3  2007
# 4  2006

# %%
# Which countries spend the largest fraction of GDP on education?
# To answer this question, consider only the rows in the dataset corresponding to indicator code `SE.XPD.TOTL.GD.ZS`,
# and write a query that returns the average value in the `value` column for each country in the dataset between the
# years 2010-2017 (including 2010 and 2017 in the average).

query = """
    SELECT country_name, AVG(value) AS avg_ed_spending_pct
    FROM `bigquery-public-data.world_bank_intl_education.international_education`
    WHERE indicator_code = 'SE.XPD.TOTL.GD.ZS' AND year >= 2010 AND year <= 2017
    GROUP BY country_name
    ORDER BY avg_ed_spending_pct DESC
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**9)  # 1 GB
query_job = client.query(query, job_config=safe_config)
query_results = query_job.to_dataframe()
query_results
# Out:
#                  country_name  avg_ed_spending_pct
# 0                        Cuba            12.837270
# 1       Micronesia, Fed. Sts.            12.467750
# 2             Solomon Islands            10.001080
# 3                     Moldova             8.372153
# 4                     Namibia             8.349610
# ..                        ...                  ...
# 152                  Cambodia             1.706404
# 153        West Bank and Gaza             1.503760
# 154               South Sudan             1.409726
# 155                    Monaco             1.409606
# 156  Central African Republic             1.214010
#
# [157 rows x 2 columns]

# %%
# Write a query below that selects the indicator code and indicator name for all codes with at least 175 rows in the year 2016.

query = """
    SELECT indicator_code, indicator_name, COUNT(1) AS num_rows
    FROM `bigquery-public-data.world_bank_intl_education.international_education`
    WHERE year = 2016
    GROUP BY indicator_code, indicator_name
    HAVING num_rows >= 175
    ORDER BY num_rows DESC
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=10**9)  # 1 GB
query_job = client.query(query, job_config=safe_config)
query_results = query_job.to_dataframe()
query_results
# Out:
#          indicator_code                                     indicator_name  \
# 0           SP.POP.TOTL                                  Population, total
# 1           SP.POP.GROW                       Population growth (annual %)
# 2        IT.NET.USER.P2                    Internet users (per 100 people)
# 3        SP.POP.1564.TO                      Population, ages 15-64, total
# 4     SP.POP.1564.FE.IN                     Population, ages 15-64, female
# 5     SP.POP.0014.FE.IN                      Population, ages 0-14, female
# 6     SP.POP.1564.TO.ZS                Population, ages 15-64 (% of total)
# 7     SP.POP.0014.MA.IN                        Population, ages 0-14, male
# 8     SP.POP.TOTL.FE.ZS                    Population, female (% of total)
# 9        SP.POP.0014.TO                       Population, ages 0-14, total
# 10    SP.POP.0014.TO.ZS                 Population, ages 0-14 (% of total)
# 11    SP.POP.1564.MA.IN                       Population, ages 15-64, male
# 12    SP.POP.TOTL.MA.ZS                      Population, male (% of total)
# 13    SP.POP.TOTL.MA.IN                                   Population, male
# 14    SP.POP.TOTL.FE.IN                                 Population, female
# 15          SH.DYN.MORT                Mortality rate, under-5 (per 1,000)
# 16       NY.GDP.PCAP.CD                       GDP per capita (current US$)
# 17       NY.GDP.MKTP.CD                 GDP at market prices (current US$)
# 18       SL.UEM.TOTL.ZS       Unemployment, total (% of total labor force)
# 19    SL.UEM.TOTL.FE.ZS     Unemployment, female (% of female labor force)
# 20       NY.GDP.PCAP.KD                 GDP per capita (constant 2005 US$)
# 21    SL.UEM.TOTL.MA.ZS         Unemployment, male (% of male labor force)
# 22       NY.GDP.MKTP.KD           GDP at market prices (constant 2005 US$)
# 23       SL.TLF.TOTL.IN                                 Labor force, total
# 24    SL.TLF.TOTL.FE.ZS       Labor force, female (% of total labor force)
# 25    NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2011 internation...
# 26    NY.GDP.PCAP.PP.CD      GDP per capita, PPP (current international $)
# 27          UIS.THAGE.0  Official entrance age to pre-primary education...
# 28    NY.GDP.MKTP.PP.CD                 GDP, PPP (current international $)
# 29    NY.GDP.MKTP.PP.KD           GDP, PPP (constant 2011 international $)
# 30    UIS.THAGE.3.A.GPV  Official entrance age to upper secondary educa...
# 31       NY.GNP.MKTP.CD                                  GNI (current US$)
# 32       NY.GNP.PCAP.CD         GNI per capita, Atlas method (current US$)
# 33    NY.GNP.MKTP.PP.CD                 GNI, PPP (current international $)
# 34    NY.GNP.PCAP.PP.CD      GNI per capita, PPP (current international $)
# 35          SE.COM.DURS           Duration of compulsory education (years)
# 36    UIS.SAP.23.GPV.G1  Population of the official entrance age to sec...
# 37  UIS.SAP.23.GPV.G1.F  Population of the official entrance age to sec...
# 38  UIS.SAP.23.GPV.G1.M  Population of the official entrance age to sec...
# 39         UIS.SAP.1.G1  Population of the official entrance age to pri...
# 40       UIS.SAP.1.G1.F  Population of the official entrance age to pri...
# 41       UIS.SAP.1.G1.M  Population of the official entrance age to pri...
# 42          SE.PRM.AGES  Official entrance age to primary education (ye...
# 43          SE.PRM.DURS  Theoretical duration of primary education (years)
# 44          SE.SEC.AGES  Official entrance age to lower secondary educa...
# 45          UIS.THDUR.0  Theoretical duration of pre-primary education ...
# 46       SE.SEC.DURS.UP  Theoretical duration of upper secondary educat...
# 47       SE.SEC.DURS.LO  Theoretical duration of lower secondary educat...
# 48          SE.SEC.DURS  Theoretical duration of secondary education (y...
#
#     num_rows
# 0        232
# 1        232
# 2        223
# 3        213
# 4        213
# 5        213
# 6        213
# 7        213
# 8        213
# 9        213
# 10       213
# 11       213
# 12       213
# 13       213
# 14       213
# 15       213
# 16       211
# 17       211
# 18       208
# 19       208
# 20       208
# 21       208
# 22       208
# 23       207
# 24       207
# 25       203
# 26       203
# 27       203
# 28       203
# 29       203
# 30       203
# 31       202
# 32       200
# 33       199
# 34       199
# 35       193
# 36       187
# 37       186
# 38       186
# 39       185
# 40       184
# 41       184
# 42       178
# 43       178
# 44       175
# 45       175
# 46       175
# 47       175
# 48       175
