# %%
from time import time

import yaml
from google.cloud import bigquery

# %%
config = yaml.load(open("credentials.yml"), yaml.Loader)
client = bigquery.Client.from_service_account_json(config["credentials_path"])

# %%
def show_amount_of_data_scanned(client, query):
    # dry_run lets us see how much data the query uses without running it
    dry_run_config = bigquery.QueryJobConfig(dry_run=True)
    query_job = client.query(query, job_config=dry_run_config)
    print("Data processed: {} GB".format(round(query_job.total_bytes_processed / 10**9, 3)))


def show_time_to_run(client, query):
    time_config = bigquery.QueryJobConfig(use_query_cache=False)
    start = time()
    query_result = client.query(query, job_config=time_config).result()
    end = time()
    print("Time to run: {} seconds".format(round(end - start, 3)))

# %%
star_query = "SELECT * FROM `bigquery-public-data.github_repos.contents`"
show_amount_of_data_scanned(client, star_query)

basic_query = "SELECT size, binary FROM `bigquery-public-data.github_repos.contents`"
show_amount_of_data_scanned(client, basic_query)
# Out:
# Data processed: 2682.118 GB
# Data processed: 2.531 GB

# %%
dataset_ref = bigquery.DatasetReference("bigquery-public-data", "github_repos")
commits_ref = bigquery.TableReference(dataset_ref, "commits")
files_ref = bigquery.TableReference(dataset_ref, "files")

commits_table = client.get_table(commits_ref)
files_table = client.get_table(files_ref)

# %%
client.list_rows(commits_table, max_results=5).to_dataframe()
# Out:
#                                      commit  \
# 0  aa358905a1b12c6fa43b6e877e907fc9d36ff0b9
# 1  5a6b6d6d29489f8587b247313804d70c45d0981f
# 2  6b6ac3b8ab7363b2238a36259c6adb7ba5d31482
# 3  e26e1f63938b983cea8d6b3229252a20c22ebbda
# 4  2a896010ccf1c86c24b2fac5cd6b9ed693d5cde6
#
#                                        tree  \
# 0  df3f8bf61bf1cb0dff3a86ebe18671792c2d4f27
# 1  ff89accb7e283ca88027d790cdb8bacf373895ab
# 2  915acc1689313e3e233d6f80338acb1629163df9
# 3  a86ea389f72e12b8905631dae68a1fd0cb5a859a
# 4  ba238795c2befc08b1276e60c4402afd9014c417
#
#                                               parent  \
# 0         [ea230a45a0e97e4d95b5f7fae9ce7ef659b60291]
# 1  [4ee369feb64ee97d71da732da0e78477efbadd76, 6aa...
# 2         [f10bea38c15c335eb71469bc0668688d2a8cd9cd]
# 3         [e263e5fcd2ced2e28bacaf63778b88561accd7a2]
# 4         [721364dbb5d1515f6deed9b132e34091822b0be1]
#
#                                               author  \
# 0  {'name': 'conda-forge-coordinator', 'email': '...
# 1  {'name': 'Rob Allen', 'email': '7e09c9d3e96378...
# 2  {'name': 'Zhihui Zhang', 'email': '9693ba60376...
# 3  {'name': 'conda-forge-coordinator', 'email': '...
# 4  {'name': 'armaneshaghi', 'email': 'f6cc8d3a4fb...
#
#                                            committer  \
# 0  {'name': 'conda-forge-coordinator', 'email': '...
# 1  {'name': 'Rob Allen', 'email': '7e09c9d3e96378...
# 2  {'name': 'Zhihui Zhang', 'email': '9693ba60376...
# 3  {'name': 'conda-forge-coordinator', 'email': '...
# 4  {'name': 'armaneshaghi', 'email': 'f6cc8d3a4fb...
#
#                                              subject  \
# 0                    Updated the qcengine feedstock.
# 1  Merge remote-tracking branch 'weierophinney/ho...
# 2          provide hook to override ZFS lockfile too
# 3                 Updated the mailchecker feedstock.
# 4                                   2014-03-06T04:30
#
#                                              message  \
# 0                    Updated the qcengine feedstock.
# 1  Merge remote-tracking branch 'weierophinney/ho...
# 2  provide hook to override ZFS lockfile too\n\ng...
# 3                 Updated the mailchecker feedstock.
# 4                                 2014-03-06T04:30\n
#
#                                              trailer difference  \
# 0                                                 []         []
# 1                                                 []         []
# 2  [{'key': 'git-svn-id', 'value': 'f2acecaac6fbd...         []
# 3                                                 []         []
# 4                                                 []         []
#
#    difference_truncated                                          repo_name  \
# 0                  True                           [conda-forge/feedstocks]
# 1                  <NA>  [MadCat34/zend-escaper, Maks3w/zend-escaper, z...
# 2                  <NA>                 [pscedu/slash2-stable, pscedu/pfl]
# 3                  True                           [conda-forge/feedstocks]
# 4                  <NA>                         [armaneshaghi/profileLife]
#
#   encoding
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None

# %%
client.list_rows(files_table, max_results=5).to_dataframe()
# Out:
#                                 repo_name                ref  \
# 0                        enzbang/diouzhtu  refs/heads/master
# 1  TheMrNomis/Latex-Flavored-Markdown-PHP  refs/heads/master
# 2  TheMrNomis/Latex-Flavored-Markdown-PHP  refs/heads/master
# 3                        xurigan/uexJPush  refs/heads/master
# 4                        xurigan/uexJPush  refs/heads/master
#
#                                        path   mode  \
# 0  gwiad_wiki_service/scripts/do-install.sh  33261
# 1                                   LFM.php  33261
# 2             PHP/LatexFlavoredMarkdown.php  33261
# 3           EUExJPush/EUExJPush/EUExJPush.h  33261
# 4             EUExJPush/uexJPush/plugin.xml  33261
#
#                                          id symlink_target
# 0  49365044eed28769152726537f00a93a68988b07           None
# 1  ef8cb78feed7f21115462b2e230c453ab1b9565a           None
# 2  d989ce59652f57efaad0f73987977dcf088c0041           None
# 3  85268b90caa19efa2b84337279fe9e3bdc963803           None
# 4  e1623bb9d8dc7db605fa4ceb6423662ad43c91b8           None

# %%
# Count the number of distinct committers and the number of files in several GitHub repositories.

slow_query = """
    SELECT COUNT(DISTINCT c.committer.name) AS num_committers,
           COUNT(DISTINCT f.id) AS num_files,
           repo_name
    FROM `bigquery-public-data.github_repos.commits` AS c,
    UNNEST(c.repo_name) AS repo_name
    INNER JOIN `bigquery-public-data.github_repos.files` AS f
    ON f.repo_name = repo_name
    WHERE f.repo_name IN ('tensorflow/tensorflow', 'facebook/react', 'Microsoft/vscode')
    GROUP BY repo_name
    ORDER BY repo_name       
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=30 * 10**10)
query_results = client.query(slow_query, job_config=safe_config).to_dataframe()
query_results

# %%
show_amount_of_data_scanned(client, slow_query)
show_time_to_run(client, slow_query)
# Out:
# Data processed: 251.854 GB
# Time to run: 9.549 seconds

# %%
# Count the number of distinct committers and the number of files in several GitHub repositories.

efficient_query = """
    WITH commits AS (
        SELECT COUNT(DISTINCT committer.name) AS num_committers,
               repo_name
        FROM `bigquery-public-data.github_repos.commits`,
        UNNEST(repo_name) AS repo_name
        WHERE repo_name IN ('tensorflow/tensorflow', 'facebook/react', 'Microsoft/vscode', 'torvalds/linux')
        GROUP BY repo_name
    ),
    files AS (
        SELECT COUNT(DISTINCT id) AS num_files,
               repo_name
        FROM `bigquery-public-data.github_repos.files`
        WHERE repo_name IN ('tensorflow/tensorflow', 'facebook/react', 'Microsoft/vscode', 'torvalds/linux')
        GROUP BY repo_name
    )
    SELECT commits.num_committers, files.num_files, files.repo_name
    FROM commits
    INNER JOIN files
    ON commits.repo_name = files.repo_name
    ORDER BY files.repo_name
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=30 * 10**10)
query_results = client.query(efficient_query, job_config=safe_config).to_dataframe()
query_results

# %%
show_amount_of_data_scanned(client, efficient_query)
show_time_to_run(client, efficient_query)
